# %% [markdown]
# #lIBRERIAS

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the Excel file
file_path = '/content/drive/MyDrive/Colab Notebooks/Tesis Maestria /ETL/Resumen.xlsx'
data = pd.read_excel(file_path)

# Display the first few rows of the dataframe to understand its structure
data.head(5)
# Out:
#                                              Informe                 Usuario  \
# 0  INFORME N° 2077-S16 ( 22531) Hernan Bejarano A...  Hernán Bejarano Acosta
# 1  INFORME N° 1667-S16 ( 21132) Leonel Murillo C ...       Leonel Murillo C.
# 2  INFORME N° 622-S16 (18045) Hector Julio Corral...  Héctor  Julio Corrales
# 3  INFORME N° 1004-S16 (1 9174) Miguel Pacheco  2...          Miguel Pacheco
# 4  INFORME N° 1006-S16 (1 9176) Carmen L Sereno  ...       Carmen L. Serrano
#
#   Identificacion Número de Laboratorio       Fecha  Departamento  \
# 0         036781             S16-22531  01-08-2016  Cundinamarca
# 1         003602             S16-21132  08-06-2016          Meta
# 2         007624             S16-18045  30-03-2016     No Indica
# 3         023015             S16-19174  26-04-2016       Córdoba
# 4         019241             S16-19176  28-04-2016    Santand er
#
#         Municipio      Vereda       Finca                           Cultivo  \
# ...

# %%
# Descripción general de los datos
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2861 entries, 0 to 2860
# Data columns (total 40 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Informe                                                      2861 non-null   object
#  1   Usuario                                                      2861 non-null   object
#  2   Identificacion                                               2861 non-null   object
#  3   Número de Laboratorio                                        2861 non-null   object
#  4   Fecha                                                        2861 non-null   object
#  5   Departamento                                                 2861 non-null   object
#  6   Municipio                                                    2861 non-null   object
# ...

# %%
data.describe(include='all')
# Out:
#                                        Informe          Usuario  \
# count                                     2861             2861
# unique                                    1240             2392
# top     No se encontró la sección del informe.  Fundación Socya
# freq                                      1621               21
# mean                                       NaN              NaN
# std                                        NaN              NaN
# min                                        NaN              NaN
# 25%                                        NaN              NaN
# 50%                                        NaN              NaN
# 75%                                        NaN              NaN
# max                                        NaN              NaN
#
#        Identificacion Número de Laboratorio       Fecha  Departamento  \
# count            2861                  2861        2861          2861
# ...

# %%
# Análisis de valores faltantes
missing_values = data.isnull().sum()
missing_percentage = (missing_values / len(data)) * 100
missing_data = pd.DataFrame({'Valores Faltantes': missing_values, 'Porcentaje (%)': missing_percentage})
missing_data
# Out:
#                                                     Valores Faltantes  \
# Informe                                                             0
# Usuario                                                             0
# Identificacion                                                      0
# Número de Laboratorio                                               0
# Fecha                                                               0
# Departamento                                                        0
# Municipio                                                           0
# Vereda                                                              0
# Finca                                                               0
# Cultivo                                                             0
# Edad                                                                0
# Diagnóstico                                                         0
# ...

# %%
# Estadísticas descriptivas de las variables numéricas
data.describe()
# Out:
#          nitrogeno      fosforo      potasio       calcio     magnesio  \
# count  2861.000000  2861.000000  2861.000000  2861.000000  2861.000000
# mean    102.012303    47.982978    83.690143    22.988710    16.928626
# std      58.097754    32.133752    76.938084    23.214728    12.374025
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      52.000000    23.000000    35.000000     7.300000     8.000000
# 50%     105.000000    46.000000    60.000000    22.000000    16.000000
# 75%     140.000000    69.000000   105.000000    29.000000    24.000000
# max     300.000000   272.000000   480.000000   120.000000    64.000000
#
#             azufre       hierro    manganeso         zinc  \
# count  2861.000000  2861.000000  2861.000000  2861.000000
# mean     33.450961     0.264411     0.506798     1.908284
# std      27.421434     1.175286     1.121709     2.019260
# min       0.000000     0.000000     0.000000     0.000000
# ...

# %%
# Seleccionar solo las columnas numéricas para el análisis de correlaciones
numeric_columns = data.select_dtypes(include=['float64', 'int64']).columns
numeric_data = data[numeric_columns]

# Recalcular la matriz de correlaciones con las columnas numéricas
correlation_matrix = numeric_data.corr()

# Visualización de la matriz de correlaciones
plt.figure(figsize=(12,8))
heatmap = sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Matriz de Correlaciones')
plt.show()

# %%
# !pip install ace_tools
# Out:
# ERROR: Could not find a version that satisfies the requirement ace_tools (from versions: none)
# ERROR: No matching distribution found for ace_tools

# %%
# Histograma de las variables numéricas
histogram_fig = data.hist(figsize=(15,10), bins=20)
plt.tight_layout()

import ace_tools as tools
tools.display_dataframe_to_user(name="Valores Faltantes", dataframe=missing_data)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-23-7da04f33d230> in <cell line: 5>()
#       3 plt.tight_layout()
#       4
# ----> 5 import ace_tools as tools
#       6 tools.display_dataframe_to_user(name="Valores Faltantes", dataframe=missing_data)
#
# ModuleNotFoundError: No module named 'ace_tools'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
